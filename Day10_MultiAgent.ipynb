# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthyenuganti-5517/ai-mentor-portfolio/blob/main/Day10_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:40:59 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:40:59 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 1d139dd8-3a0a-4ec7-b9a3-3aa5bd53626a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 5bb43a67-b4d2-4309-a941-cae90f1c1188                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital preparation for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes sections on Advanced Coding, Verbal Ability, Reasoning Ability,  │
# │  Quantitative Ability, and sometimes specific technical questions.                                              │
# │  *   **Technical Interview:** Focuses on Data Structures & Algorithms, core CS fundamentals (OS, DBMS, OOPs,    │
# │  Networking), project discussions, and knowledge of specific technologies relevant to digital roles.            │
# │  *   **Managerial Interview (Optional):** May assess problem-solving approach, leadership potential, project    │
# │  experience, and ability to handle real-world scenarios.                                                        │
# │  *   **HR Interview:** Evaluates communication skills, cultural fit, career aspirations, and verifies academic  │
# │  background and other personal details.                                                                         │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Programming Languages:** Strong proficiency in at least one of Java, Python, C++, C# is crucial,         │
# │  especially for advanced coding.                                                                                │
# │  *   **Data Structures & Algorithms (DSA):** Expertise in fundamental and advanced DSA concepts is paramount    │
# │  for solving complex coding problems.                                                                           │
# │  *   **Core Computer Science:** Solid understanding of Operating Systems, Database Management Systems (DBMS),   │
# │  Object-Oriented Programming (OOPs), and Computer Networks.                                                     │
# │  *   **Cloud Technologies:** Familiarity with concepts and services from major cloud providers (AWS, Azure,     │
# │  GCP) is highly valued for many digital roles.                                                                  │
# │  *   **Modern Web/App Development:** Knowledge of front-end (React, Angular, Vue.js), back-end frameworks       │
# │  (Spring Boot, Django, Node.js), and database technologies (SQL, NoSQL) for full-stack roles.                   │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Percentage:** Generally requires a minimum aggregate of 60% or 6.0 CGPA throughout academic     │
# │  career (10th, 12th, Diploma, Graduation).                                                                      │
# │  *   **Educational Qualification:** Open to B.E./B.Tech/M.E./M.Tech/MCA/M.Sc students from specific branches    │
# │  (e.g., CSE, IT, ECE, EEE).                                                                                     │
# │  *   **Year of Passing:** Primarily targets final-year students, but recent graduates meeting specific          │
# │  criteria might also be eligible.                                                                               │
# │  *   **Backlogs:** Typically, no active backlogs are allowed at the time of applying or during the selection    │
# │  process.                                                                                                       │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Higher Compensation:** TCS Digital roles offer significantly higher salary packages compared to the      │
# │  regular TCS Ninja profiles.                                                                                    │
# │  *   **Focus on Niche Technologies:** Increased demand for skills in Artificial Intelligence/Machine Learning,  │
# │  Cloud Computing, Cybersecurity, IoT, and Data Science.                                                         │
# │  *   **Practical Problem-Solving:** Greater emphasis on candidates' ability to solve real-world problems and    │
# │  implement efficient solutions rather than just theoretical knowledge.                                          │
# │  *   **Full-Stack & Cloud Expertise:** A growing preference for candidates with full-stack development          │
# │  capabilities and hands-on experience with cloud platforms.                                                     │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA:** Dedicate significant time to practice Data Structures and Algorithms on platforms like     │
# │  LeetCode, HackerRank, and GeeksforGeeks.                                                                       │
# │  *   **Strengthen Core CS:** Thoroughly revise OS, DBMS, OOPs, and Networking concepts, as these are            │
# │  frequently tested in technical interviews.                                                                     │
# │  *   **Build Projects:** Work on practical projects, especially those leveraging modern technologies (e.g.,     │
# │  cloud, AI/ML, web frameworks) to showcase your skills.                                                         │
# │  *   **One Strong Language:** Become highly proficient in at least one programming language (Java, Python,      │
# │  C++) with a deep understanding of its features and libraries.                                                  │
# │  *   **Aptitude & Verbal Practice:** Regularly practice quantitative aptitude, logical reasoning, and verbal    │
# │  ability questions to clear the initial online assessment.                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 4c2b2d64-afb9-44dc-ab65-7719a5b515dc                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers exciting roles with            │
# │  competitive packages, pushing the boundaries of innovation. This brief outlines key areas to focus on for      │
# │  your journey to becoming a part of TCS's elite digital force.                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Process                                                                                      │
# │                                                                                                                 │
# │  TCS Digital's selection is a multi-stage process designed to identify top talent with strong technical and     │
# │  problem-solving abilities:                                                                                     │
# │                                                                                                                 │
# │  *   **Online Assessment:** This comprehensive test typically covers:                                           │
# │      *   **Advanced Coding:** Expect complex problems requiring efficient algorithms.                           │
# │      *   **Verbal Ability, Reasoning Ability, Quantitative Ability:** Essential for evaluating general          │
# │  aptitude.                                                                                                      │
# │      *   **Technical MCQs:** Sometimes includes questions on core computer science fundamentals.                │
# │  *   **Technical Interview:** A deep dive into your technical prowess. Expect questions on:                     │
# │      *   Data Structures & Algorithms (DSA)                                                                     │
# │      *   Core CS fundamentals (OS, DBMS, OOPs, Networking)                                                      │
# │      *   Detailed discussions on your projects and internships.                                                 │
# │      *   Specific technologies relevant to digital roles (e.g., Cloud, AI/ML, Web Dev).                         │
# │  *   **Managerial Interview (Optional):** May assess your problem-solving approach, leadership potential,       │
# │  ability to handle real-world scenarios, and project experience.                                                │
# │  *   **HR Interview:** Focuses on communication skills, cultural fit, career aspirations, and verification of   │
# │  academic and personal details.                                                                                 │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  To excel in TCS Digital roles, a strong foundation in these areas is crucial:                                  │
# │                                                                                                                 │
# │  *   **Programming Languages:** Master at least one of these: Java, Python, C++, C#. Proficiency in advanced    │
# │  features and libraries is key for coding rounds.                                                               │
# │  *   **Data Structures & Algorithms (DSA):** Expertise in fundamental and advanced DSA concepts is paramount    │
# │  for solving complex problems efficiently.                                                                      │
# │  *   **Core Computer Science:** Solid understanding of Operating Systems (OS), Database Management Systems      │
# │  (DBMS), Object-Oriented Programming (OOPs) principles, and Computer Networks.                                  │
# │  *   **Cloud Technologies:** Familiarity with concepts and services from major cloud providers (AWS, Azure,     │
# │  GCP) is highly valued for modern digital solutions.                                                            │
# │  *   **Modern Web/App Development:** Knowledge of front-end (React, Angular, Vue.js), back-end frameworks       │
# │  (Spring Boot, Django, Node.js), and database technologies (SQL, NoSQL) for full-stack opportunities.           │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the basic academic requirements to qualify:                                                    │
# │                                                                                                                 │
# │  *   **Academic Percentage:** Generally requires a minimum aggregate of 60% or 6.0 CGPA throughout your         │
# │  academic career (10th, 12th, Diploma, Graduation).                                                             │
# │  *   **Educational Qualification:** Typically open to B.E./B.Tech/M.E./M.Tech/MCA/M.Sc students from specific   │
# │  branches (e.g., CSE, IT, ECE, EEE).                                                                            │
# │  *   **Year of Passing:** Primarily targets final-year students, but recent graduates meeting specific          │
# │  criteria might also be eligible.                                                                               │
# │  *   **Backlogs:** Usually, no active backlogs are allowed at the time of application or during the selection   │
# │  process.                                                                                                       │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  TCS Digital is evolving, reflecting industry demand for specialized skills:                                    │
# │                                                                                                                 │
# │  *   **Higher Compensation:** TCS Digital roles offer significantly higher salary packages compared to the      │
# │  regular TCS Ninja profiles.                                                                                    │
# │  *   **Focus on Niche Technologies:** Increased demand for proficiency in Artificial Intelligence/Machine       │
# │  Learning, Cloud Computing, Cybersecurity, Internet of Things (IoT), and Data Science.                          │
# │  *   **Practical Problem-Solving:** Greater emphasis on candidates' ability to solve real-world problems and    │
# │  implement efficient, scalable solutions, moving beyond just theoretical knowledge.                             │
# │  *   **Full-Stack & Cloud Expertise:** A growing preference for candidates with full-stack development          │
# │  capabilities and hands-on experience with cloud platforms.                                                     │
# │                                                                                                                 │
# │  ### 5. Effective Preparation Tips                                                                              │
# │                                                                                                                 │
# │  Strategize your preparation to maximize your chances of success:                                               │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practice Data Structures and Algorithms on platforms like     │
# │  LeetCode, HackerRank, and GeeksforGeeks. Aim for consistent problem-solving.                                   │
# │  *   **Strengthen Core CS:** Thoroughly revise OS, DBMS, OOPs, and Networking concepts. These are frequently    │
# │  tested and form the bedrock of technical interviews.                                                           │
# │  *   **Build Projects:** Work on practical, hands-on projects, especially those leveraging modern technologies  │
# │  (e.g., cloud, AI/ML, web frameworks) to showcase your applied skills.                                          │
# │  *   **One Strong Language:** Become highly proficient in at least one programming language (Java, Python,      │
# │  C++). Understand its nuances, data structures, and standard libraries deeply.                                  │
# │  *   **Aptitude & Verbal Practice:** Regularly practice quantitative aptitude, logical reasoning, and verbal    │
# │  ability questions to comfortably clear the initial online assessment.                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Success in TCS Digital requires dedication and strategic preparation. Start early, focus on core concepts,     │
# │  and build practical skills. Your future in digital innovation awaits!                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers exciting roles with competitive packages, pushing the boundaries of innovation. This brief outlines key areas to focus on for your journey to becoming a part of TCS's elite digital force.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is a multi-stage process designed to identify top talent with strong technical and problem-solving abilities:
#
# *   **Online Assessment:** This comprehensive test typically covers:
#     *   **Advanced Coding:** Expect complex problems requiring efficient algorithms.
#     *   **Verbal Ability, Reasoning Ability, Quantitative Ability:** Essential for evaluating general aptitude.
#     *   **Technical MCQs:** Sometimes includes questions on core computer science fundamentals.
# *   **Technical Interview:** A deep dive into your technical prowess. Expect questions on:
#     *   Data Structures & Algorithms (DSA)
#     *   Core CS fundamentals (OS, DBMS, OOPs, Networking)
#     *   Detailed discussions on your projects and internships.
#     *   Specific technologies relevant to digital roles (e.g., Cloud, AI/ML, Web Dev).
# *   **Managerial Interview (Optional):** May assess your problem-solving approach, leadership potential, ability to handle real-world scenarios, and project experience.
# *   **HR Interview:** Focuses on communication skills, cultural fit, career aspirations, and verification of academic and personal details.
#
# ### 2. Essential Technical Stack
#
# To excel in TCS Digital roles, a strong foundation in these areas is crucial:
#
# *   **Programming Languages:** Master at least one of these: Java, Python, C++, C#. Proficiency in advanced features and libraries is key for coding rounds.
# *   **Data Structures & Algorithms (DSA):** Expertise in fundamental and advanced DSA concepts is paramount for solving complex problems efficiently.
# *   **Core Computer Science:** Solid understanding of Operating Systems (OS), Database Management Systems (DBMS), Object-Oriented Programming (OOPs) principles, and Computer Networks.
# *   **Cloud Technologies:** Familiarity with concepts and services from major cloud providers (AWS, Azure, GCP) is highly valued for modern digital solutions.
# *   **Modern Web/App Development:** Knowledge of front-end (React, Angular, Vue.js), back-end frameworks (Spring Boot, Django, Node.js), and database technologies (SQL, NoSQL) for full-stack opportunities.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the basic academic requirements to qualify:
#
# *   **Academic Percentage:** Generally requires a minimum aggregate of 60% or 6.0 CGPA throughout your academic career (10th, 12th, Diploma, Graduation).
# *   **Educational Qualification:** Typically open to B.E./B.Tech/M.E./M.Tech/MCA/M.Sc students from specific branches (e.g., CSE, IT, ECE, EEE).
# *   **Year of Passing:** Primarily targets final-year students, but recent graduates meeting specific criteria might also be eligible.
# *   **Backlogs:** Usually, no active backlogs are allowed at the time of application or during the selection process.
#
# ### 4. Recent Hiring Trends
#
# TCS Digital is evolving, reflecting industry demand for specialized skills:
#
# *   **Higher Compensation:** TCS Digital roles offer significantly higher salary packages compared to the regular TCS Ninja profiles.
# *   **Focus on Niche Technologies:** Increased demand for proficiency in Artificial Intelligence/Machine Learning, Cloud Computing, Cybersecurity, Internet of Things (IoT), and Data Science.
# *   **Practical Problem-Solving:** Greater emphasis on candidates' ability to solve real-world problems and implement efficient, scalable solutions, moving beyond just theoretical knowledge.
# *   **Full-Stack & Cloud Expertise:** A growing preference for candidates with full-stack development capabilities and hands-on experience with cloud platforms.
#
# ### 5. Effective Preparation Tips
#
# Strategize your preparation to maximize your chances of success:
#
# *   **Master DSA:** Dedicate significant time to practice Data Structures and Algorithms on platforms like LeetCode, HackerRank, and GeeksforGeeks. Aim for consistent problem-solving.
# *   **Strengthen Core CS:** Thoroughly revise OS, DBMS, OOPs, and Networking concepts. These are frequently tested and form the bedrock of technical interviews.
# *   **Build Projects:** Work on practical, hands-on projects, especially those leveraging modern technologies (e.g., cloud, AI/ML, web frameworks) to showcase your applied skills.
# *   **One Strong Language:** Become highly proficient in at least one programming language (Java, Python, C++). Understand its nuances, data structures, and standard libraries deeply.
# *   **Aptitude & Verbal Practice:** Regularly practice quantitative aptitude, logical reasoning, and verbal ability questions to comfortably clear the initial online assessment.
#
# ---
#
# Success in TCS Digital requires dedication and strategic preparation. Start early, focus on core concepts, and build practical skills. Your future in digital innovation awaits!

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 5055

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes sections on Advanced Coding, Verbal Ability, Reasoning Ability, Quantitative Ability, and sometimes specific technical questions.
# *   **Technical Interview:** Focuses on Data Structures & Algorithms, core CS fundamentals (OS, DBMS, OOPs, Networking), project discussions, and knowledge of specific technologies relevant to digital roles.
# *   **Managerial Interview (Optional):** May assess problem-solving approach, leadership potential, project experience, and ability to handle real-world scenarios.
# *   **HR Interview:** Evaluates communication skills, cultural fit, career aspirations, and verifies academic background and other personal details.
#
# ### Tech
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers exciting roles with competitive packages, pushing the boundaries of innovation. This brief outlines key areas to focus on for your journey to becoming a part of TCS's elite digital force.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is a multi-stage process designed to identify top talent with strong technical and problem-solving abilities:
#
# *   **Online Assessment:** This comprehensive test typically covers:
#     *   **Advanced Coding:** Expect complex problems requiring efficient algorithms.
#     *   **Verbal Ability, Reasoning Ability, Quantitative Ability:** Essential for evaluating general aptitude.
#     *   **Technical MCQs:** Sometimes includes questions on

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers exciting roles with competitive packages, pushing the boundaries of innovation. This brief outlines key areas to focus on for your journey to becoming a part of TCS's elite digital force.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is a multi-stage process designed to identify top talent with strong technical and problem-solving abilities:
#
# *   **Online Assessment:** This comprehensive test typically covers:
#     *   **Advanced Coding:** Expect complex problems requiring efficient algorithms.
#     *   **Verbal Ability, Reasoning Ability, Quantitative Ability:** Essential for evaluating general aptitude.
#     *   **Technical MCQs:** Sometimes includes questions on core computer science fundamentals.
# *   **Technical Interview:** A deep dive into your technical prowess. Expect questions on:
#     *   Data Structures & Algorithms (DSA)
#     *   Core CS fundamentals (OS, DBMS, OOPs, Networking)
#     *   Detailed discussions on your projects and internships.
#     *   Specific technologies relevant to digital roles (e.g., Cloud, AI/ML, Web Dev).
# *   **Managerial Interview (Optional):** May assess your problem-solving approach, leadership potential, ability to handle real-world scenarios, and project experience.
# *   **HR Interview:** Focuses on communication skills, cultural fit, career aspirations, and verification of academic and personal details.
#
# ### 2. Essential Technical Stack
#
# To excel in TCS Digital roles, a strong foundation in these areas is crucial:
#
# *   **Programming Languages:** Master at least one of these: Java, Python, C++, C#. Proficiency in advanced features and libraries is key for coding rounds.
# *   **Data Structures & Algorithms (DSA):** Expertise in fundamental and advanced DSA concepts is paramount for solving complex problems efficiently.
# *   **Core Computer Science:** Solid understanding of Operating Systems (OS), Database Manag
